# %% [markdown]
# # Generate XML annotation files and JPEGImages from TIFF files.
#
# * This notebook assumes that datasets have been stored locally on this machine and bounding regions annotated within Fiji/ImageJ.
# * If this is not the case, then you either want to maybe use the OMERO version of this script:
# dset01_create_anno_from_OMERO.ipynb  (This other notebook allows you to import ROI from tiff files directly).
# * Creating a dataset forms the foundation of training material used to train one of many object detection algorithms.
# * N.B. Once Finished here it is also important to add the information about this dataset to the config/dataset_spec.txt file.
# * N.B. The next step after this is to run is to run the notebook dset02_create_anno_formats. This next notebook is used  create the
# configuration files associated with the dataset and also allows you to group datasets together for larger training.

# %%
import getpass
import matplotlib.pylab as plt
import os
import numpy as np
from scipy import ndimage
import ijroi
from ijroi.ij_roi import Roi
from ijroi.ijpython_decoder import decode_ij_roi
import sys
sys.path.append('../src')
import convert_voc_to_other as cvto

# %% [markdown]
# ### Creating Folder structure for new dataset
# First we need to create a folder structure on the file-system.

# %%
#Create the folder structure.
dataset_home_dir = "/Users/dominicwaithe/Documents/collaborators/WaitheD/micro_vision/cell_datasets/"
dataset_name = "USO2_rfp_pcna_live_class" #e.g. erythroblast_dapi_glycophorinA_FOXO3_class
year_acquisition = "2021"
class_name = "cell - USO2 rfp pcna live" #Classes to have in this dataset.
###########
## The above has to be added to config/dataset_spec.txt file.
###########

xml_path = dataset_home_dir+dataset_name+'/'+year_acquisition+'/Annotations'
jpg_path = dataset_home_dir+dataset_name+'/'+year_acquisition+'/JPEGImages'
# checking whether folder/directory exists
if not os.path.exists(dataset_home_dir+dataset_name):
    os.mkdir(dataset_home_dir+dataset_name)
if not os.path.exists(dataset_home_dir+dataset_name+'/'+year_acquisition+'/'):
    os.mkdir(dataset_home_dir+dataset_name+'/'+year_acquisition+'/')
for dirm in [xml_path,jpg_path]:
    if not os.path.exists(dirm):
        os.mkdir(dirm)

# %% [markdown]
# ### Specify folder containing the tiff files.
# and collect those files with ij_metadata (rather than OME metadata).

# %%
from tifffile import TiffFile


dir_to_read = "/Users/dominicwaithe/Documents/collaborators/WaitheD/micro_vision/acquisitions/2020_11_13_RFP-PCNA_DAPI/2020_03_28_RFP_extension/"
myimages = [] #list of image filenames
dirFiles = os.listdir(dir_to_read) #list of directory files
dirFiles.sort() #good initial sort but doesnt sort numerically very well
sorted(dirFiles) #sort numerically in ascending order

for file in dirFiles: #filter out all non jpgs
    if '.tiff' in file[-5:] or '.tif' in file[-4:]:
        myimages.append(file)
print (len(myimages))
print (myimages)
ij_tiff =[]
ome_tiff = []
for tiff in myimages:
    img_to_open = dir_to_read+tiff
    tf_img = TiffFile(img_to_open)
    
    if tf_img.ome_metadata !=None:
        print('I think this is an OME tiff.')
        ome_tiff.append(tiff)
    elif tf_img.imagej_metadata !=None:
        print('I think this is an IJ tiff.')
        ij_tiff.append(tiff)
        
    tf_img.close()
# Out:
# 168
# ['00000.tif', '00001.tif', '00002.tif', '00003.tif', '00004.tif', '00005.tif', '00006.tif', '00007.tif', '00008.tif', '00009.tif', '00010.tif', '00011.tif', '00012.tif', '00013.tif', '00014.tif', '00015.tif', '00016.tif', '00017.tif', '00018.tif', '00019.tif', '00020.tif', '00021.tif', '00022.tif', '00023.tif', '00024.tif', '00025.tif', '00026.tif', '00027.tif', '00028.tif', '00029.tif', '00036.tif', '00037.tif', '00038.tif', '00039.tif', '00040.tif', '00041.tif', '00042.tif', '00043.tif', '00044.tif', '00045.tif', '00046.tif', '00047.tif', '00048.tif', '00049.tif', '00050.tif', '00051.tif', '00052.tif', '00053.tif', '00054.tif', '00055.tif', '00056.tif', '00057.tif', '00058.tif', '00059.tif', '00060.tif', '00061.tif', '00062.tif', '00063.tif', '00064.tif', '00065.tif', '00066.tif', '00067.tif', '00068.tif', '00069.tif', '00070.tif', '00071.tif', '00072.tif', '00073.tif', '00074.tif', '00075.tif', '00076.tif', '00077.tif', '00078.tif', '00079.tif', '00080.tif', '00081.tif', '00082.tif', '00083.tif', '00084.tif', '00085.tif', '00086.tif', '00087.tif', '00088.tif', '00089.tif', '00090.tif', '00091.tif', '00092.tif', '00093.tif', '00094.tif', '00095.tif', '00096.tif', '00097.tif', '00098.tif', '00099.tif', '00100.tif', '00101.tif', '00108.tif', '00109.tif', '00110.tif', '00111.tif', '00112.tif', '00113.tif', '00114.tif', '00115.tif', '00116.tif', '00117.tif', '00118.tif', '00119.tif', '00120.tif', '00121.tif', '00122.tif', '00123.tif', '00124.tif', '00125.tif', '00126.tif', '00127.tif', '00128.tif', '00129.tif', '00130.tif', '00131.tif', '00133.tif', '00134.tif', '00135.tif', '00136.tif', '00137.tif', '00138.tif', '00139.tif', '00140.tif', '00141.tif', '00142.tif', '00143.tif', '00144.tif', '00145.tif', '00146.tif', '00147.tif', '00148.tif', '00149.tif', '00150.tif', '00151.tif', '00152.tif', '00153.tif', '00154.tif', '00155.tif', '00156.tif', '00157.tif', '00158.tif', '00159.tif', '00160.tif', '00161.tif', '00162.tif', '00164.tif', '00165.tif', '00166.tif', '00167.tif', '00169.tif', '00170.tif', '00171.tif', '00172.tif', '00173.tif', '00174.tif', '00175.tif', '00176.tif', '00177.tif', '00178.tif', '00179.tif', '00183.tif', '00184.tif', '00185.tif']
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.
# I think this is an IJ tiff.

# %% [markdown]
# ### Generate XML annotation files and JPEGImages from ImageJ Tifffiles.
# This cell takes a folder of ImageJ tiff images and annotations located on local computer.
# This script assumes that images have been annotated in fiji/ImageJ and the cell class has been used to label the ROI.

# %%
#If you want to name your output images with a sequence (recommended), then set rename_with_seq=True
rename_with_seq = True
start_index = 2500 #Choose a sensible unique start.
#If rename_with_seq = False, then the input name will be reused, with .jpg ending.
annotator_name = "Waithe" 
override = True 
scale_factor = 1
ch_to_take = 0


ct = 0
for tiff in ij_tiff:
    if rename_with_seq:
        output_name = str(start_index+ct).zfill(6)
    else:
        output_name = tiff.split('.')[:-1][0]
    
    print('input name:',tiff,'output name: '+str(output_name)+'.jpg')
    tfile = TiffFile(dir_to_read+tiff)
    img_shape = tfile.asarray().shape

    overlay_arr = []
    if 'Overlays' in tfile.imagej_metadata:
        overlays = tfile.imagej_metadata['Overlays']
        if overlays.__class__.__name__ == 'list':
            #Multiple overlays and so iterate.
            for overlay in overlays:

                overlay_arr.append(decode_ij_roi(overlay,img_shape))
        else:
            #One overlay.
                overlay_arr.append(decode_ij_roi(overlays,img_shape))
    else:
        print('no Overlays present in file.')
    
    roi_list = []
    for i in range(0,overlay_arr.__len__()):
        if overlay_arr[i]:
            roi_class_name = str(overlay_arr[i].name).replace("\x00", "")
            x = overlay_arr[i].x
            y = overlay_arr[i].y
            width = overlay_arr[i].width
            height = overlay_arr[i].height
            roi_list.append([x, y, width, height, roi_class_name])
            
    
    raw_img = tfile.asarray()
    if raw_img.shape.__len__() > 2:
        raw_img = raw_img[ch_to_take,:,:]
    print(raw_img.shape)
    
    assert raw_img.shape.__len__() == 2, "image should only have 2-dimensions."
    
    
    sorted_img = np.sort(raw_img.flatten())
    sat_fac = 0.3 #Matches Fiji/ImageJ saturation factor of 0.3%
    img_min = int(np.ceil(sorted_img.shape[0]*((sat_fac/2.)/100.)))
    img_max = int(np.floor(sorted_img.shape[0]*((100.-(sat_fac/2.))/100.)))

    lower_bound = sorted_img[img_min]
    upper_bound = sorted_img[img_max]

    #This is very similar to the ImageJ/Fiji methodoloy when saving JPEGs but isn't exactly the same.
    lut = np.concatenate([
            np.zeros(lower_bound, dtype=np.uint16),
            np.linspace(0, 255, upper_bound - lower_bound).astype(np.uint16),
            np.ones(2**16 - upper_bound, dtype=np.uint16) * 255
        ])

    bit_img = lut[raw_img].astype(np.uint8)
    corr_img = ndimage.interpolation.zoom(bit_img,scale_factor)

    out_img = np.zeros((corr_img.shape[0],corr_img.shape[1],3))
    out_img[:,:,0] = corr_img
    out_img[:,:,1] = corr_img
    out_img[:,:,2] = corr_img

    #assert raw_img.shape[0] == 1024, "input image is unexpected size"
    #assert out_img.shape[0] == 512, "output image is unexpected size"
    
    out_img = out_img.astype(np.uint8)
    jpg_file = str(output_name)+".jpg"
    #Save the JPEG image out to the folder
    plt.imsave(jpg_path+'/'+jpg_file, out_img)
    #Save the XML annotation out.
    cvto.write_xml(xml_path, roi_list, output_name, dataset_name, class_name,override, year_acquisition, out_img.shape[1], out_img.shape[0], scale_factor)
    ct+=1
# Out:
# input name: 00000.tif output name: 002500.jpg
# (512, 512)
# input name: 00001.tif output name: 002501.jpg
# (512, 512)
# input name: 00002.tif output name: 002502.jpg
# (512, 512)
# input name: 00003.tif output name: 002503.jpg
# (512, 512)
# input name: 00004.tif output name: 002504.jpg
# (512, 512)
# input name: 00005.tif output name: 002505.jpg
# (512, 512)
# input name: 00006.tif output name: 002506.jpg
# (512, 512)
# input name: 00007.tif output name: 002507.jpg
# (512, 512)
# input name: 00008.tif output name: 002508.jpg
# (512, 512)
# input name: 00009.tif output name: 002509.jpg
# (512, 512)
# input name: 00010.tif output name: 002510.jpg
# (512, 512)
# input name: 00011.tif output name: 002511.jpg
# (512, 512)
# input name: 00012.tif output name: 002512.jpg
# (512, 512)
# input name: 00013.tif output name: 002513.jpg
# (512, 512)
# input name: 00014.tif output name: 002514.jpg
# (512, 512)
# input name: 00015.tif output name: 002515.jpg
# (512, 512)
# input name: 00016.tif output name: 002516.jpg
# (512, 512)
# input name: 00017.tif output name: 002517.jpg
# (512, 512)
# input name: 00018.tif output name: 002518.jpg
# (512, 512)
# input name: 00019.tif output name: 002519.jpg
# (512, 512)
# input name: 00020.tif output name: 002520.jpg
# (512, 512)
# input name: 00021.tif output name: 002521.jpg
# (512, 512)
# input name: 00022.tif output name: 002522.jpg
# (512, 512)
# input name: 00023.tif output name: 002523.jpg
# (512, 512)
# input name: 00024.tif output name: 002524.jpg
# (512, 512)
# input name: 00025.tif output name: 002525.jpg
# (512, 512)
# input name: 00026.tif output name: 002526.jpg
# (512, 512)
# input name: 00027.tif output name: 002527.jpg
# (512, 512)
# input name: 00028.tif output name: 002528.jpg
# (512, 512)
# input name: 00029.tif output name: 002529.jpg
# (512, 512)
# input name: 00036.tif output name: 002530.jpg
# (512, 512)
# input name: 00037.tif output name: 002531.jpg
# (512, 512)
# input name: 00038.tif output name: 002532.jpg
# (512, 512)
# input name: 00039.tif output name: 002533.jpg
# (512, 512)
# input name: 00040.tif output name: 002534.jpg
# (512, 512)
# input name: 00041.tif output name: 002535.jpg
# (512, 512)
# input name: 00042.tif output name: 002536.jpg
# (512, 512)
# input name: 00043.tif output name: 002537.jpg
# (512, 512)
# input name: 00044.tif output name: 002538.jpg
# (512, 512)
# input name: 00045.tif output name: 002539.jpg
# (512, 512)
# input name: 00046.tif output name: 002540.jpg
# (512, 512)
# input name: 00047.tif output name: 002541.jpg
# (512, 512)
# input name: 00048.tif output name: 002542.jpg
# (512, 512)
# input name: 00049.tif output name: 002543.jpg
# (512, 512)
# input name: 00050.tif output name: 002544.jpg
# (512, 512)
# input name: 00051.tif output name: 002545.jpg
# (512, 512)
# input name: 00052.tif output name: 002546.jpg
# (512, 512)
# input name: 00053.tif output name: 002547.jpg
# (512, 512)
# input name: 00054.tif output name: 002548.jpg
# (512, 512)
# input name: 00055.tif output name: 002549.jpg
# (512, 512)
# input name: 00056.tif output name: 002550.jpg
# (512, 512)
# input name: 00057.tif output name: 002551.jpg
# (512, 512)
# input name: 00058.tif output name: 002552.jpg
# (512, 512)
# input name: 00059.tif output name: 002553.jpg
# (512, 512)
# input name: 00060.tif output name: 002554.jpg
# (512, 512)
# input name: 00061.tif output name: 002555.jpg
# (512, 512)
# input name: 00062.tif output name: 002556.jpg
# (512, 512)
# input name: 00063.tif output name: 002557.jpg
# (512, 512)
# input name: 00064.tif output name: 002558.jpg
# (512, 512)
# input name: 00065.tif output name: 002559.jpg
# (512, 512)
# input name: 00066.tif output name: 002560.jpg
# (512, 512)
# input name: 00067.tif output name: 002561.jpg
# (512, 512)
# input name: 00068.tif output name: 002562.jpg
# (512, 512)
# input name: 00069.tif output name: 002563.jpg
# (512, 512)
# input name: 00070.tif output name: 002564.jpg
# (512, 512)
# input name: 00071.tif output name: 002565.jpg
# (512, 512)
# input name: 00072.tif output name: 002566.jpg
# (512, 512)
# input name: 00073.tif output name: 002567.jpg
# (512, 512)
# input name: 00074.tif output name: 002568.jpg
# (512, 512)
# input name: 00075.tif output name: 002569.jpg
# (512, 512)
# input name: 00076.tif output name: 002570.jpg
# (512, 512)
# input name: 00077.tif output name: 002571.jpg
# (512, 512)
# input name: 00078.tif output name: 002572.jpg
# (512, 512)
# input name: 00079.tif output name: 002573.jpg
# (512, 512)
# input name: 00080.tif output name: 002574.jpg
# (512, 512)
# input name: 00081.tif output name: 002575.jpg
# (512, 512)
# input name: 00082.tif output name: 002576.jpg
# (512, 512)
# input name: 00083.tif output name: 002577.jpg
# (512, 512)
# input name: 00084.tif output name: 002578.jpg
# (512, 512)
# input name: 00085.tif output name: 002579.jpg
# (512, 512)
# input name: 00086.tif output name: 002580.jpg
# (512, 512)
# input name: 00087.tif output name: 002581.jpg
# (512, 512)
# input name: 00088.tif output name: 002582.jpg
# (512, 512)
# input name: 00089.tif output name: 002583.jpg
# (512, 512)
# input name: 00090.tif output name: 002584.jpg
# (512, 512)
# input name: 00091.tif output name: 002585.jpg
# (512, 512)
# input name: 00092.tif output name: 002586.jpg
# (512, 512)
# input name: 00093.tif output name: 002587.jpg
# (512, 512)
# input name: 00094.tif output name: 002588.jpg
# (512, 512)
# input name: 00095.tif output name: 002589.jpg
# (512, 512)
# input name: 00096.tif output name: 002590.jpg
# (512, 512)
# input name: 00097.tif output name: 002591.jpg
# (512, 512)
# input name: 00098.tif output name: 002592.jpg
# (512, 512)
# input name: 00099.tif output name: 002593.jpg
# (512, 512)
# input name: 00100.tif output name: 002594.jpg
# (512, 512)
# input name: 00101.tif output name: 002595.jpg
# (512, 512)
# input name: 00108.tif output name: 002596.jpg
# (512, 512)
# input name: 00109.tif output name: 002597.jpg
# (512, 512)
# input name: 00110.tif output name: 002598.jpg
# (512, 512)
# input name: 00111.tif output name: 002599.jpg
# (512, 512)
# input name: 00112.tif output name: 002600.jpg
# (512, 512)
# input name: 00113.tif output name: 002601.jpg
# (512, 512)
# input name: 00114.tif output name: 002602.jpg
# (512, 512)
# input name: 00115.tif output name: 002603.jpg
# (512, 512)
# input name: 00116.tif output name: 002604.jpg
# (512, 512)
# input name: 00117.tif output name: 002605.jpg
# (512, 512)
# input name: 00118.tif output name: 002606.jpg
# (512, 512)
# input name: 00119.tif output name: 002607.jpg
# (512, 512)
# input name: 00120.tif output name: 002608.jpg
# (512, 512)
# input name: 00121.tif output name: 002609.jpg
# (512, 512)
# input name: 00122.tif output name: 002610.jpg
# (512, 512)
# input name: 00123.tif output name: 002611.jpg
# (512, 512)
# input name: 00124.tif output name: 002612.jpg
# (512, 512)
# input name: 00125.tif output name: 002613.jpg
# (512, 512)
# input name: 00126.tif output name: 002614.jpg
# (512, 512)
# input name: 00127.tif output name: 002615.jpg
# (512, 512)
# input name: 00128.tif output name: 002616.jpg
# (512, 512)
# input name: 00129.tif output name: 002617.jpg
# (512, 512)
# input name: 00130.tif output name: 002618.jpg
# (512, 512)
# input name: 00131.tif output name: 002619.jpg
# (512, 512)
# input name: 00133.tif output name: 002620.jpg
# (512, 512)
# input name: 00134.tif output name: 002621.jpg
# (512, 512)
# input name: 00135.tif output name: 002622.jpg
# (512, 512)
# input name: 00136.tif output name: 002623.jpg
# (512, 512)
# input name: 00137.tif output name: 002624.jpg
# (512, 512)
# input name: 00138.tif output name: 002625.jpg
# (512, 512)
# input name: 00139.tif output name: 002626.jpg
# (512, 512)
# input name: 00140.tif output name: 002627.jpg
# (512, 512)
# input name: 00141.tif output name: 002628.jpg
# (512, 512)
# input name: 00142.tif output name: 002629.jpg
# (512, 512)
# input name: 00143.tif output name: 002630.jpg
# (512, 512)
# input name: 00144.tif output name: 002631.jpg
# (512, 512)
# input name: 00145.tif output name: 002632.jpg
# (512, 512)
# input name: 00146.tif output name: 002633.jpg
# (512, 512)
# input name: 00147.tif output name: 002634.jpg
# (512, 512)
# input name: 00148.tif output name: 002635.jpg
# (512, 512)
# input name: 00149.tif output name: 002636.jpg
# (512, 512)
# input name: 00150.tif output name: 002637.jpg
# (512, 512)
# input name: 00151.tif output name: 002638.jpg
# (512, 512)
# input name: 00152.tif output name: 002639.jpg
# (512, 512)
# input name: 00153.tif output name: 002640.jpg
# (512, 512)
# input name: 00154.tif output name: 002641.jpg
# (512, 512)
# input name: 00155.tif output name: 002642.jpg
# (512, 512)
# input name: 00156.tif output name: 002643.jpg
# (512, 512)
# input name: 00157.tif output name: 002644.jpg
# (512, 512)
# input name: 00158.tif output name: 002645.jpg
# (512, 512)
# input name: 00159.tif output name: 002646.jpg
# (512, 512)
# input name: 00160.tif output name: 002647.jpg
# (512, 512)
# input name: 00161.tif output name: 002648.jpg
# (512, 512)
# input name: 00162.tif output name: 002649.jpg
# (512, 512)
# input name: 00164.tif output name: 002650.jpg
# (512, 512)
# input name: 00165.tif output name: 002651.jpg
# (512, 512)
# input name: 00166.tif output name: 002652.jpg
# (512, 512)
# input name: 00167.tif output name: 002653.jpg
# (512, 512)
# input name: 00169.tif output name: 002654.jpg
# (512, 512)
# input name: 00170.tif output name: 002655.jpg
# (512, 512)
# input name: 00171.tif output name: 002656.jpg
# (512, 512)
# input name: 00172.tif output name: 002657.jpg
# (512, 512)
# input name: 00173.tif output name: 002658.jpg
# (512, 512)
# input name: 00174.tif output name: 002659.jpg
# (512, 512)
# input name: 00175.tif output name: 002660.jpg
# (512, 512)
# input name: 00176.tif output name: 002661.jpg
# (512, 512)
# input name: 00177.tif output name: 002662.jpg
# (512, 512)
# input name: 00178.tif output name: 002663.jpg
# (512, 512)
# input name: 00179.tif output name: 002664.jpg
# (512, 512)
# input name: 00183.tif output name: 002665.jpg
# (512, 512)
# input name: 00184.tif output name: 002666.jpg
# (512, 512)
# input name: 00185.tif output name: 002667.jpg
# (512, 512)
